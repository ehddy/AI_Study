# %% [markdown]
# ## 1. 라이브러리 및 데이터 불러오기

# %%
# 전처리
import pandas as pd
import numpy as np


# 시각화
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import missingno as msno
import scipy.stats as st
from scipy.stats import norm, skew 
from sklearn import set_config

import warnings
warnings.filterwarnings('ignore')


# 결측치 처리
from sklearn.impute import SimpleImputer

# plt 테마 설정 
plt.style.use(['seaborn-white'])

plt.rc('font', family='AppleGothic')

# 맥 폰트 
plt.rcParams['axes.unicode_minus'] = False


# 데이터셋 분할 & 교차검증 & 하이퍼파라미터 튜닝 
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV


# 데이터 전처리 (인코딩, 표준화, 정규화)
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline 
from sklearn.compose import ColumnTransformer
# 모델링
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.ensemble import RandomForestRegressor


# 성능지표 
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %% [markdown]
# - 윈도우

# %%
# # 학습용 데이터 불러오기
# train_data = pd.read_csv('C:/Users/Innovation/Desktop/김동요/jupyter/인공지능/과제 4/train.csv')

# # 테스트용 데이터 불러오기 
# test_data = pd.read_csv('C:/Users/Innovation/Desktop/김동요/jupyter/인공지능/과제 4/test.csv')

# # 제출용 데이터 불러오기 
# submission_data = pd.read_csv('C:/Users/Innovation/Desktop/김동요/jupyter/인공지능/과제 4/submission.csv')

# %% [markdown]
# - 맥북

# %%
train_data = pd.read_csv('/Users/dongyokim/main/jupyter/2022:2/인공지능/과제 4/train.csv')

# 테스트용 데이터 불러오기 
test_data = pd.read_csv('/Users/dongyokim/main/jupyter/2022:2/인공지능/과제 4/test.csv')

# 제출용 데이터 불러오기 
submission_data = pd.read_csv('submission.csv')

# %% [markdown]
# ### 1) 데이터 확인

# %%
train_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
test_data.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
print('train_data shape : {}'.format(train_data.shape))
print('train_data의 결측치 : {}'.format(sum(train_data.isna().sum())))
print('test_data shape : {}'.format(test_data.shape))
print('test_data의 결측치 : {}'.format(sum(test_data.isna().sum())))
# Out:
# train_data shape : (1460, 81)
# train_data의 결측치 : 6965
# test_data shape : (1459, 80)
# test_data의 결측치 : 7000

# %% [markdown]
# - train_data는 행이 1460개이며, test_data는 행이 1459개이다.
# - train_data의 결측값들은 총 6965개이며, test_data의 결측값들은 총 7000개이다.

# %%
train_data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1455    False
# 1456    False
# 1457    False
# 1458    False
# 1459    False
# Length: 1460, dtype: bool

# %%
print(f'train_data 중복값: {train_data.duplicated().sum()}, ({np.round(100*train_data.duplicated().sum()/len(train_data),1)}%)')
print('')
print(f'test_data 중복값: {test_data.duplicated().sum()}, ({np.round(100*test_data.duplicated().sum()/len(test_data),1)}%)')
# Out:
# train_data 중복값: 0, (0.0%)
#
# test_data 중복값: 0, (0.0%)

# %% [markdown]
# - train_data와 test_data 모두 중복된 key 값(인덱스)이 없다는 것을 확인하였다.

# %%
# 변수명 및 변수타입 확인
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
numerical_feats = list(train_data.select_dtypes(exclude='object'))

print('Dataset의 수치형 변수는 총 {}개 입니다.'.format(len(numerical_feats)))


cat_feats = list(train_data.select_dtypes(include='object'))

print('Dataset의 범주형 변수는 총 {}개 입니다.'.format(len(cat_feats)))
# Out:
# Dataset의 수치형 변수는 총 38개 입니다.
# Dataset의 범주형 변수는 총 43개 입니다.

# %% [markdown]
# - train_data에는 총 80개의 변수가 존재하며, 수치형 변수는 38개, 범주형 변수는 43개로 구성되어 있다.

# %% [markdown]
# ---
# ## 2. EDA(탐색적 데이터 분석)

# %% [markdown]
# ### 1) 기술 통계량 확인

# %%
train_data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
test_data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage       LotArea  OverallQual  \
# count  1459.000000  1459.000000  1232.000000   1459.000000  1459.000000
# mean   2190.000000    57.378341    68.580357   9819.161069     6.078821
# std     421.321334    42.746880    22.376841   4955.517327     1.436812
# min    1461.000000    20.000000    21.000000   1470.000000     1.000000
# 25%    1825.500000    20.000000    58.000000   7391.000000     5.000000
# 50%    2190.000000    50.000000    67.000000   9399.000000     6.000000
# 75%    2554.500000    70.000000    80.000000  11517.500000     7.000000
# max    2919.000000   190.000000   200.000000  56600.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1459.000000  1459.000000   1459.000000  1444.000000  1458.000000  ...
# mean      5.553804  1971.357779   1983.662783   100.709141   439.203704  ...
# std       1.113740    30.390071     21.130467   177.625900   455.268042  ...
# ...

# %% [markdown]
# ### 2) 타겟 변수(Sale Price)

# %%
# 타겟 변수의 가격 
train_data['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# - 분산과 표준편차가 크다는 것을 알 수 있으며, 분포가 한쪽으로 치우쳐져 있다.
# - 로그변환을 해줄 필요가 있다.

# %%
sns.distplot(train_data['SalePrice'])
plt.title('Original Sale Price Histogram')
plt.show()

# %%
fig = plt.figure()
res = st.probplot(train_data['SalePrice'], plot=plt)
plt.show()

# %% [markdown]
# - 정규성 과정을 위해 QQplot을 그렸는데, 오른쪽으로 꼬리가 긴 분포인 것을 알 수 있으며 right skewed 하다는 것을 알 수 있다. -> 로그변환 필요

# %%
# 로그 변환 실행 
train_data['SalePrice']=np.log1p(train_data['SalePrice'])

# %%
# 로그 변환 후의 히스토그램 
sns.distplot(train_data['SalePrice'])
plt.title('Original Sale Price Histogram')
plt.show()

# %% [markdown]
# - 로그변환 후에 정규 분포의 모양을 나타내며 분포가 고르게 퍼져있다는 것을 알 수 있다

# %%
# 종속변수와의 상관관계 파악
cor_mat= train_data[numerical_feats].corr()
cor_with_tar=cor_mat.sort_values(['SalePrice'],ascending=False)
print("The most relevant features (numeric) for the target are :")
cor_with_tar.SalePrice
# Out:
# The most relevant features (numeric) for the target are :
# SalePrice        1.000000
# OverallQual      0.817185
# GrLivArea        0.700927
# GarageCars       0.680625
# GarageArea       0.650888
# TotalBsmtSF      0.612134
# 1stFlrSF         0.596981
# FullBath         0.594771
# YearBuilt        0.586570
# YearRemodAdd     0.565608
# GarageYrBlt      0.541073
# TotRmsAbvGrd     0.534422
# Fireplaces       0.489450
# MasVnrArea       0.430809
# BsmtFinSF1       0.372023
# LotFrontage      0.355879
# WoodDeckSF       0.334135
# OpenPorchSF      0.321053
# 2ndFlrSF         0.319300
# HalfBath         0.313982
# LotArea          0.257320
# BsmtFullBath     0.236224
# BsmtUnfSF        0.221985
# BedroomAbvGr     0.209043
# ScreenPorch      0.121208
# PoolArea         0.069798
# MoSold           0.057330
# 3SsnPorch        0.054900
# BsmtFinSF2       0.004832
# BsmtHalfBath    -0.005149
# Id              -0.017942
# MiscVal         -0.020021
# OverallCond     -0.036868
# ...

# %%
# using a corelation map to visualize features with high corelation.
cor_mat= train_data[['OverallQual','GrLivArea','GarageCars','GarageArea','TotalBsmtSF','1stFlrSF','FullBath',
             'YearBuilt','YearRemodAdd','GarageYrBlt','TotRmsAbvGrd','SalePrice']].corr()
mask = np.array(cor_mat)
mask[np.tril_indices_from(mask)] = False
fig=plt.gcf()
fig.set_size_inches(30,12)
sns.heatmap(data=cor_mat,mask=mask,square=True,annot=True,cbar=True, cmap='gray')
# Out:
# <AxesSubplot:>

# %% [markdown]
# - 타겟 변수와 0.5 이상의 높은 상관성을 보여주는 독립변수들이 다수 존재한다.
#
# - 집의 전반적인 재료와 마감을 평가(OverallQual) 점수가 높을수록, 거실의 면적이 클수록(GrLivArea), 차고의 크기(GarageArea)가 크고 수용할 수 있는 차의 대수(GarageCars)가 많을수록, 지하실의 면적(TotalBsmtSF)이 클수록 주택의 가격(SalePrice)이 커진다는 것을 알 수 있다.
#
# - 독립변수들 사이에서도 높은 상관성을 보이는 변수쌍이 있는데, (GarageCars, GrageArea), (1stFlrSF, TotalBsmtSF),(GrLivArea, TotRmsAbvGrd) 등이 있다. -> (다중공선성 확인 필요)

# %% [markdown]
# ### 2) 수치형 변수

# %% [markdown]
# - 타겟 변수를 제외한 수치형 변수 중 어느 것도 정규 분포의 모습을 보이지 않으므로 다른 수치형 변수들도 변환해주어야 한다.

# %%
# 다른 수치형 변수들도 확인
f = pd.melt(train_data, value_vars=numerical_feats)
g = sns.FacetGrid(f, col="variable",  col_wrap=2, sharex=False, sharey=False)
g = g.map(sns.distplot, "value")

# %% [markdown]
# - TotalBsmtSF, KitchenAbvGr, LotFrontage, LotArea 등 일부 독립 변수는 로그 변환을 해야할 필요가 보인다 .

# %% [markdown]
# ### 3) 범주형 변수

# %%
def plot_cat(feature):
    sns.countplot(data=train_data,x=feature)
    ax=sns.countplot(data=train_data,x=feature)

# %%
plot_cat('OverallQual')

# %% [markdown]
# - 대부분의 집들은 5~7(보통, 보통이상, 좋음)의 평가를 받았다는 것을 알 수 있다.

# %%
plot_cat('FullBath')

# %% [markdown]
# - 매물로 나온 집들의 화장실 개수는 보통 2개가 가장 많은 것으로 나타났다.

# %%
 plot_cat('TotRmsAbvGrd')

# %% [markdown]
# - 대부분의 집들은 보통 5-7개의 방을 갖고 있다.

# %%
plot_cat('GarageCars')

# %% [markdown]
# - 대부분의 집들은 2대의 차를 주차할 수 있는 차고 공간을 갖고 있다.

# %% [markdown]
# - 위에 변수들은 info()에서는 수치형 변수로 나타나지만 실제로는 명목형 변수이다. <- 레이블 인코딩을 했다고 가정

# %%
def boxplot(x, y, **kwargs):
    sns.boxplot(x=x, y=y)
    x=plt.xticks(rotation=90)
f = pd.melt(train_data, id_vars=['SalePrice'], value_vars=cat_feats)
g = sns.FacetGrid(f, col="variable",  col_wrap=2, sharex=False, sharey=False, size=5)
g = g.map(boxplot, "value", "SalePrice")

# %% [markdown]
# - 이웃은 집값은 타겟 변수에(집값) 큰 영향을 미친다는 것을 알 수 있다.
# - 또한, 재산에 수영장이 있으면 가격이 상당히 증가하는 것을 알  수 있다.
# - 난로의 퀄리티 등급이 좋을수록 가격이 증가한다.

# %% [markdown]
# ### 4) 결합 변수

# %%
fig, ax = plt.subplots()
ax.scatter(x = train_data['GrLivArea'], y = train_data['SalePrice'])
plt.ylabel('SalePrice')
plt.xlabel('GrLivArea')
plt.show()

# %% [markdown]
# - 오른쪽 하단의 두개의 이상치를 발견했으며(평수가 매우 큰데 가격이 평균정도), 이를 제거해야할 필요를 느낌

# %%
train_data = train_data.drop(train_data[(train_data['GrLivArea']>4000) & (train_data['SalePrice']<13)].index)

# %%
train_data.reset_index(drop=True, inplace=True)

# %%
fig, ax = plt.subplots()
ax.scatter(x = train_data['GrLivArea'], y = train_data['SalePrice'])
plt.ylabel('SalePrice')
plt.xlabel('GrLivArea')
plt.show()

# %%
# garage area -> area가 1200이상인 데이터를 이상치로 처리하여 삭제
fig, ax = plt.subplots()
ax.scatter(x =(train_data['GarageArea']), y = train_data['SalePrice'])
plt.ylabel('SalePrice')
plt.xlabel('GarageArea')
plt.show()

# %%
train_data = train_data.drop(train_data[(train_data['GarageArea']>1200) & (train_data['SalePrice']<12.5)].index)
train_data.reset_index(drop=True, inplace=True)

# %%
# garage area -> area가 1200이상인 데이터를 이상치로 처리하여 삭제
fig, ax = plt.subplots()
ax.scatter(x =(train_data['GarageArea']), y = train_data['SalePrice'])
plt.ylabel('SalePrice')
plt.xlabel('GarageArea')
plt.show()

# %%
# basment area -> 지하실 평수가 3000이상인 데이터를 이상치로 처리 -> 삭제
fig, ax = plt.subplots()
ax.scatter(x =(train_data['TotalBsmtSF']), y = train_data['SalePrice'])
plt.ylabel('SalePrice')
plt.xlabel('TotalBsmtSF')
plt.show()

# %%
train_data = train_data.drop(train_data[train_data['TotalBsmtSF'] >3000].index)
train_data.reset_index(drop=True, inplace=True)

# %%
# basment area -> 지하실 평수가 3000이상인 데이터를 이상치로 처리 -> 삭제
fig, ax = plt.subplots()
ax.scatter(x =(train_data['TotalBsmtSF']), y = train_data['SalePrice'])
plt.ylabel('SalePrice')
plt.xlabel('TotalBsmtSF')
plt.show()

# %% [markdown]
# - 이상치 제거 완료

# %% [markdown]
# ---
# ## 3. 데이터 전처리 및 변수 선택

# %% [markdown]
# ### 1) 결측치 처리

# %%
# 긱 변수당 결측치의 개수 확인
train_data.isnull().sum().sort_values(ascending=False)
# Out:
# PoolQC         1446
# MiscFeature    1399
# Alley          1361
# Fence          1171
# FireplaceQu     689
#                ...
# ExterQual         0
# Exterior2nd       0
# Exterior1st       0
# RoofMatl          0
# SalePrice         0
# Length: 81, dtype: int64

# %%
nan_all_data = (train_data.isnull().sum())
nan_all_data= nan_all_data.drop(nan_all_data[nan_all_data== 0].index).sort_values(ascending=False)
nan_all_data
miss_df = pd.DataFrame({'결측치 개수' :nan_all_data, '결측치 비중' : nan_all_data / train_data.shape[0]})
miss_df
# Out:
#               결측치 개수    결측치 비중
# PoolQC          1446  0.995868
# MiscFeature     1399  0.963499
# Alley           1361  0.937328
# Fence           1171  0.806474
# FireplaceQu      689  0.474518
# LotFrontage      257  0.176997
# GarageType        81  0.055785
# GarageYrBlt       81  0.055785
# GarageFinish      81  0.055785
# GarageQual        81  0.055785
# GarageCond        81  0.055785
# BsmtExposure      38  0.026171
# BsmtFinType1      37  0.025482
# BsmtFinType2      37  0.025482
# BsmtCond          37  0.025482
# BsmtQual          37  0.025482
# MasVnrArea         8  0.005510
# MasVnrType         8  0.005510
# Electrical         1  0.000689

# %% [markdown]
# - 결측치의 비중이 매우 높은 열들은 삭제한다.

# %%
train_data.drop(['PoolQC','Alley','Fence','Id','MiscFeature', 'FireplaceQu'],axis=1,inplace=True)  
test_data.drop(['PoolQC','Alley','Fence','Id','MiscFeature', 'FireplaceQu'],axis=1,inplace=True)

# %%
#LotFrontage(다른 공간에 열결되어 있는 통로들의 피트)
print(train_data['LotFrontage'].dtype)
plt.scatter(x=np.log1p(train_data['LotFrontage']),y=train_data['SalePrice'])
cr=train_data.corr()
print(train_data['LotFrontage'].describe())
print("The corelation of the LotFrontage with the Target : " , cr.loc['LotFrontage','SalePrice'])
# Out:
# float64
# count    1195.000000
# mean       69.689540
# std        23.155649
# min        21.000000
# 25%        59.000000
# 50%        69.000000
# 75%        80.000000
# max       313.000000
# Name: LotFrontage, dtype: float64
# The corelation of the LotFrontage with the Target :  0.3741495528145913

# %% [markdown]
# - 다음으로 결측치의 비중이 약간 높은 LotFrontage 변수를 살펴보면, 타겟변수인 SalePrice와 어느 정도 상관관계를 보여주기 때문에 삭제하기 보다는 결측치를 평균값으로 대체

# %%
train_data['LotFrontage'].fillna(np.mean(train_data['LotFrontage']),inplace=True)
test_data['LotFrontage'].fillna(np.mean(train_data['LotFrontage']),inplace=True)
train_data['LotFrontage'].isna().sum()
# Out:
# 0

# %%
# 차고(Garage)관련 변수들은 대부분 SalePrice의 유의미한 영향을 끼친다는 것을 파악했기 때문에 삭제 대신 결측치를 특정 값으로 대체해준다. 
# SimpleImputer 라이브러리를 사용하여 차고 관련 수치형 변수는 결측치를 모두 0으로, 범주형 변수는 'None'으로 변경 

# 수치형 변수 결측치 처리 -> 0으로 변환 
imputer_cols_num = ["GarageYrBlt", "GarageArea", "GarageCars"]
imputer = SimpleImputer(strategy='constant', fill_value=0)
imputer.fit(train_data[imputer_cols_num])
train_data[imputer_cols_num] = imputer.transform(train_data[imputer_cols_num])
test_data[imputer_cols_num] = imputer.transform(test_data[imputer_cols_num])

# 카테고리 변수 결측치 처리 -< None으로 변환 
imputer_cols_cate = ["GarageQual", "GarageFinish", "GarageCond", 'GarageType']
imputer = SimpleImputer(strategy='constant', fill_value='None')
imputer.fit(train_data[imputer_cols_cate])
train_data[imputer_cols_cate] = imputer.transform(train_data[imputer_cols_cate])
test_data[imputer_cols_cate] = imputer.transform(test_data[imputer_cols_cate])

# %%
# 지하실(basement) 관련 변수들도 차고 변수들과 같이 결측치 처리 

# 수치형 변수 결측치 처리 -> 0으로 변환 
imputer_cols_num = ['BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF','TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath']
imputer = SimpleImputer(strategy='constant', fill_value=0)
imputer.fit(train_data[imputer_cols_num])
train_data[imputer_cols_num] = imputer.transform(train_data[imputer_cols_num])
test_data[imputer_cols_num] = imputer.transform(test_data[imputer_cols_num])

# 카테고리 변수 결측치 처리 -< None으로 변환 
imputer_cols_cate = ['BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2']
imputer = SimpleImputer(strategy='constant', fill_value='None')
imputer.fit(train_data[imputer_cols_cate])
train_data[imputer_cols_cate] = imputer.transform(train_data[imputer_cols_cate])
test_data[imputer_cols_cate] = imputer.transform(test_data[imputer_cols_cate])

# %%
# MasVnrArea를 0으로 MasVnrType을 'None'으로 결측치 처리 
train_data['MasVnrArea'].fillna(0,inplace=True)
test_data['MasVnrArea'].fillna(0,inplace=True)
print(train_data['MasVnrArea'].isnull().sum())

train_data['MasVnrType'].fillna('None',inplace=True)
test_data['MasVnrType'].fillna('None',inplace=True)
print(train_data['MasVnrType'].isnull().sum())
# Out:
# 0
# 0

# %%
train_data['MSZoning'].value_counts().sort_index().plot.pie(shadow=True, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# - 판매하는 지역이 대다수 RL(Residential Low Density)인것을 알 수 있으며, 결측치도 최빈값인 RL로 변경해준다.

# %%
#MSZoning(판매 지역 구분)
train_data['MSZoning'].fillna(train_data['MSZoning'].mode()[0],inplace=True)
test_data['MSZoning'].fillna(test_data['MSZoning'].mode()[0],inplace=True)
print(train_data['MSZoning'].isnull().sum())
# Out:
# 0

# %%
# utilities
sns.factorplot(data=train_data,kind='box',x='Utilities',y='SalePrice',size=5,aspect=1.5)
plt.show()

# %%
train_data['Utilities'].value_counts()
# Out:
# AllPub    1451
# NoSeWa       1
# Name: Utilities, dtype: int64

# %% [markdown]
# - Utilities 변수는 하나의 범주의 값이 1개 밖에 들어있지 않기 때문에, 무의미한 변수라고 판단 -> 열 삭제

# %%
train_data.drop(['Utilities'],axis=1,inplace=True)
test_data.drop(['Utilities'],axis=1,inplace=True)

# %%
train_data.shape
# Out:
# (1452, 74)

# %%
test_data.shape
# Out:
# (1459, 73)

# %%
train_data[imputer_cols_cate]
# Out:
#      BsmtQual BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2
# 0          Gd       TA           No          GLQ          Unf
# 1          Gd       TA           Gd          ALQ          Unf
# 2          Gd       TA           Mn          GLQ          Unf
# 3          TA       Gd           No          ALQ          Unf
# 4          Gd       TA           Av          GLQ          Unf
# ...       ...      ...          ...          ...          ...
# 1447       Gd       TA           No          Unf          Unf
# 1448       Gd       TA           No          ALQ          Rec
# 1449       TA       Gd           No          GLQ          Unf
# 1450       TA       TA           Mn          GLQ          Rec
# 1451       TA       TA           No          BLQ          LwQ
#
# [1452 rows x 5 columns]

# %%
# 남은 변수들은 최빈값으로 대체 
for col in ['SaleType','KitchenQual','Exterior2nd','Exterior1st','Electrical', 'Functional']:
    train_data[col].fillna(train_data[col].mode()[0],inplace=True)
    test_data[col].fillna(test_data[col].mode()[0],inplace=True)
    print(train_data[col].isnull().sum())
# Out:
# 0
# 0
# 0
# 0
# 0
# 0

# %%
nan_all_data = (train_data.isnull().sum())
nan_all_data= nan_all_data.drop(nan_all_data[nan_all_data== 0].index).sort_values(ascending=False)
nan_all_data
miss_df = pd.DataFrame({'결측치 개수' :nan_all_data, '결측치 비중' : nan_all_data / train_data.shape[0]})
miss_df
# Out:
# Empty DataFrame
# Columns: [결측치 개수, 결측치 비중]
# Index: []

# %%
nan_all_data = (test_data.isnull().sum())
nan_all_data= nan_all_data.drop(nan_all_data[nan_all_data== 0].index).sort_values(ascending=False)
nan_all_data
miss_df = pd.DataFrame({'결측치 개수' :nan_all_data, '결측치 비중' : nan_all_data / train_data.shape[0]})
miss_df
# Out:
# Empty DataFrame
# Columns: [결측치 개수, 결측치 비중]
# Index: []

# %% [markdown]
# - 결측치 처리 완료

# %% [markdown]
# ### 2) 데이터 분할

# %%
X = train_data.drop('SalePrice', axis=1)
y = train_data['SalePrice']

X_test = test_data.copy()

# %% [markdown]
# ### 3) 데이터 스케일링

# %%
# 수치형 변수들 중 왜도가 0.5 이상인 변수들은 모두 로그변환 
numeric_feats = X.dtypes[X.dtypes != "object"].index

skewed_feats = X[numeric_feats].apply(lambda x: skew(x.dropna())) #compute skewness
skewed_feats = skewed_feats[skewed_feats > 1]
skewed_feats = skewed_feats.index

X[skewed_feats] = np.log1p(X[skewed_feats])
X_test[skewed_feats] = np.log1p(X_test[skewed_feats])

# %%
# 다른 수치형 변수들도 확인
f = pd.melt(X, value_vars=numeric_feats)
g = sns.FacetGrid(f, col="variable",  col_wrap=2, sharex=False, sharey=False)
g = g.map(sns.distplot, "value")

# %% [markdown]
# - 분포가 안정적으로 바뀜 -> 표준화도 진행

# %%
# 수치형 변수와 범주형 변수 전처리 진행 
# 수치형 변수는 표준화, 범주형 변수는 원핫 인코딩 진행 
numerical_cols = X.dtypes[X.dtypes != "object"].index
categorical_cols = X.dtypes[X.dtypes == "object"].index

# 수치형 변수 표준화 진행
numerical_transformer = Pipeline(steps=[('scaler', StandardScaler())])

# 범주형 변수 원핫 인코딩 진행 
categorical_transformer = Pipeline(steps=[('onehot', OneHotEncoder(drop='if_binary', handle_unknown='ignore',sparse=False))])

# 전처리한 데이터 결합 
ct = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols),
        ('cat', categorical_transformer, categorical_cols)],
        remainder='passthrough')

X = ct.fit_transform(X)
X_test = ct.transform(X_test)

print('Training set shape:', X.shape)
# Out:
# Training set shape: (1452, 274)

# %% [markdown]
# - 최종적으로 274개의 행 생성 완료

# %%
# 학습 데이터 내부에서 검증 데이터 셋 생성
# 생존 여부 클래스가 0이 더 많기 때문에 균등하게 나눠주기 위해 stratify 옵션 적용
X_train, X_test_1, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=11)

# %%
print(X_train.shape, y_train.shape)
print(X_test_1.shape, y_test.shape)
# Out:
# (1161, 274) (1161,)
# (291, 274) (291,)

# %% [markdown]
# ---
# ## 4. 모델링

# %%
# 성능 지표를 출력하는 함수 구현


def rmse(y, pred):
    return np.sqrt(mean_squared_error(y, pred))
    
    
def r_2(y, pred):
    return r2_score(y, pred)
    
    
def evaluate_regr(y, pred):
    rmse_val = rmse(y, pred)
    mae_val = mean_absolute_error(y, pred)
    r_score = r_2(y, pred)
    print('R2: {0:.3f}, RMSE: {1:.3f}, MAE: {2:.3f}'.format(r_score, rmse_val, mae_val))

# %%
# 모델과 학습/테스트 데이터 세트를 입력하면 성능, 평가 수치를 반환 
def get_model_predict(model, X_data, y_target):
    model.fit(X_data, y_target)
    pred = model.predict(X_data)
    
    print('###', model.__class__.__name__, '###')
    evaluate_regr(y_target, pred)
    print()

# %%
# 디중 선형 회귀 모델 사용 
lr_reg = LinearRegression()

# 규제 모델 Ridge, Lasso 학습, 예측, 비교 
ridge_reg = Ridge()

lasso_reg = Lasso()


models = [lr_reg, ridge_reg, lasso_reg]

for model in models:
    get_model_predict(model,X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <module>
#       1 # 디중 선형 회귀 모델 사용
# ----> 2 lr_reg = LinearRegression()
#       4 # 규제 모델 Ridge, Lasso 학습, 예측, 비교
#       5 ridge_reg = Ridge()
#
# NameError: name 'LinearRegression' is not defined

# %% [markdown]
# ---
# ## 5. 교차 검증

# %%
from sklearn.model_selection import cross_val_score

def get_avg_rmse_cv(models):
    
    for model in models:
        # 분할하지 않고 전체 데이터로 cross_val_score() 수행. 모델별 CV RMSE 값과 평균 RMSE 출력 
        rmse_list = np.sqrt(-cross_val_score(model, X, y, scoring='neg_mean_squared_error', cv=5))
        
        rmse_avg = np.mean(rmse_list)
        print('\n{0} CV RMSE 값 리스트: {1}'.format(model.__class__.__name__, np.round(rmse_list, 3)))
        print('{0} CV 평균 RMSE 값: {1}'.format(model.__class__.__name__, np.round(rmse_avg, 3)))
    
    
# 앞 예제에서 학습한 lr_reg, ridge_reg, lasso_reg 모델의 CV RMSE 값 출력 
models = [lr_reg, ridge_reg, lasso_reg]
get_avg_rmse_cv(models)
# Out:
# LinearRegression CV RMSE 값 리스트: [1.02786233e+09 8.86713915e+08 5.52364464e+08 2.86585638e+08
#  1.16021784e+09]
# LinearRegression CV 평균 RMSE 값: 782748838.386
#
# Ridge CV RMSE 값 리스트: [0.109 0.118 0.129 0.106 0.114]
# Ridge CV 평균 RMSE 값: 0.115
#
# Lasso CV RMSE 값 리스트: [0.387 0.418 0.409 0.381 0.393]
# Lasso CV 평균 RMSE 값: 0.397

# %% [markdown]
# ---
# ## 6. 하이퍼파라미터 튜닝

# %%
def print_best_params(model, params):
    grid_model = GridSearchCV(model, param_grid=params, scoring='neg_mean_squared_error', cv=5)
    grid_model.fit(X, y)
    rmse = np.sqrt(-1*grid_model.best_score_)
    print('{0} 5 CV 시 최적 평균 RMSE 값:{1}, 최적 alpha:{2}'.format(model.__class__.__name__, np.round(rmse, 3), grid_model.best_params_))
    

ridge_params = {'alpha':[0.05, 0.1, 1, 5 ,8, 10, 12, 15, 20]}
lasso_params = {'alpha': [0.001, 0.005, 0.008, 0.05, 0.03, 0.1, 0.5, 1, 5, 10]}
print_best_params(ridge_reg, ridge_params)
print_best_params(lasso_reg, lasso_params)
# Out:
# Ridge 5 CV 시 최적 평균 RMSE 값:0.111, 최적 alpha:{'alpha': 12}
# Lasso 5 CV 시 최적 평균 RMSE 값:0.11, 최적 alpha:{'alpha': 0.001}

# %%
# 앞에 최적화 alpha 값으로 학습 데이터로 학습, 테스트 데이터로 예측 및 평가 수행 
lr_reg = LinearRegression()

ridge_reg = Ridge(alpha=12)

lasso_reg = Lasso(alpha=0.001)


models = [lr_reg, ridge_reg, lasso_reg]


for model in models:
    get_model_predict(model,X_train, y_train)
# Out:
# ### LinearRegression ###
# R2: 0.954, RMSE: 0.084, MAE: 0.061
#
# ### Ridge ###
# R2: 0.943, RMSE: 0.093, MAE: 0.065
#
# ### Lasso ###
# R2: 0.935, RMSE: 0.100, MAE: 0.070

# %% [markdown]
# - 최종 모델은 Ridge 선택

# %% [markdown]
# ---
# ## 6. 테스트 데이터 예측값 제출

# %%
pred = ridge_reg.predict(X_test)
# 로그변환해준 타겟값 다시 원 상태로 변환 
submission_data['SalePrice'] = np.expm1(pred)

# %%
submission_data
# Out:
#         Id      SalePrice
# 0     1461  119727.914390
# 1     1462  154942.343602
# 2     1463  182296.161693
# 3     1464  196580.233028
# 4     1465  195618.521351
# ...    ...            ...
# 1454  2915   90332.529555
# 1455  2916   79688.744916
# 1456  2917  175236.859940
# 1457  2918  119993.471455
# 1458  2919  228024.763239
#
# [1459 rows x 2 columns]

# %%
# csv 추출 
submission_data.to_csv('submission_18010244_김동요.csv', index=False)
